# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid
plt.grid()
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot
plt.barh(x_axis, y_axis, color="m", label='Boston')
plt.gca().invert_yaxis()
# Add a title and axes labels
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots() 
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots() 
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Change color to cyan.
plt.barh(x_axis, y_axis, color="c", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots() 
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Change color to cyan.
plt.barh(x_axis, y_axis, color="c", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
#Change color to cyan.
plt.barh(x_axis, y_axis, color="c", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
#Change color to cyan.
plt.scatter(x_axis, y_axis, color="r", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
legend('Chicago')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/2419140575.py in <module>
# ----> 1 legend('Chicago')
#
# NameError: name 'legend' is not defined

# %%
plt.scatter(x_axis, y_axis, color="r", legend='Chicago')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/2717019572.py in <module>
# ----> 1 plt.scatter(x_axis, y_axis, color="r", legend='Chicago')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2810         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
# -> 2811         **({"data": data} if data is not None else {}), **kwargs)
#    2812     sci(__ret)
#    2813     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4420                 )
#    4421         collection.set_transform(mtransforms.IdentityTransform())
# -> 4422         collection.update(kwargs)
#    4423
#    4424         if colors is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'PathCollection' object has no property 'legend'

# %%
plt.scatter(x,y)
plt.legend('Chicago')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/1492531255.py in <module>
# ----> 1 plt.scatter(x,y)
#       2 plt.legend('Chicago')
#
# NameError: name 'x' is not defined

# %%
plt.scatter(x_axis, y_axis)
plt.legend('Chicago')

# %%
#Change color to red.
plt.scatter(x_axis, y_axis, color="r", legend='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/3778244687.py in <module>
#       1 #Change color to red.
# ----> 2 plt.scatter(x_axis, y_axis, color="r", legend='Chicago')
#       3 # Add title and axis labels.
#       4 plt.xlabel("Date")
#       5 plt.ylabel("Fare($)")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2810         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
# -> 2811         **({"data": data} if data is not None else {}), **kwargs)
#    2812     sci(__ret)
#    2813     return __ret
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4420                 )
#    4421         collection.set_transform(mtransforms.IdentityTransform())
# -> 4422         collection.update(kwargs)
#    4423
#    4424         if colors is None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'PathCollection' object has no property 'legend'

# %%
#Change color to red.
plt.scatter(x_axis, y_axis, color="r", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend(legend='Chicago)
# Out:
#   File "C:\Users\m163075\AppData\Local\Temp/ipykernel_6492/2477568147.py", line 7
#     plt.legend(legend='Chicago)
#                                ^
# SyntaxError: EOL while scanning string literal

# %%
#Change color to red.
plt.scatter(x_axis, y_axis, color="r", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend('Chicago')

# %%
plt.xlim(min, max)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/1804231609.py in <module>
# ----> 1 plt.xlim(min, max)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in xlim(*args, **kwargs)
#    1697     if not args and not kwargs:
#    1698         return ax.get_xlim()
# -> 1699     ret = ax.set_xlim(*args, **kwargs)
#    1700     return ret
#    1701
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in set_xlim(self, left, right, emit, auto, xmin, xmax)
#    3714                 f"Attempting to set identical left == right == {left} results "
#    3715                 f"in singular transformations; automatically expanding.")
# -> 3716         reverse = left > right
#    3717         left, right = self.xaxis.get_major_locator().nonsingular(left, right)
#    3718         left, right = self.xaxis.limit_range_for_scale(left, right)
#
# TypeError: '>' not supported between instances of 'builtin_function_or_method' and 'builtin_function_or_method'

# %%
plt.xlim(Jan, Dec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/3678620567.py in <module>
# ----> 1 plt.xlim(Jan, Dec)
#
# NameError: name 'Jan' is not defined

# %%
plt.xlim(0, 12)
# Out:
# (0.0, 12.0)

# %%
#Change color to red and set legend to "Chicago".
plt.scatter(x_axis, y_axis, color="r", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend('Chicago')
#invert y_axis so that Jan is on top
plt.gca().invert_yaxis()
# Add limit to the x-axis data
plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %%
#Change color to red and set legend to "Chicago".
plt.scatter(x_axis, y_axis, color="r", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend('Chicago')
#invert y_axis so that Jan is on top
plt.gca().invert_yaxis()
# Add limit to the x-axis data
plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %%
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Change color to red and set legend to "Chicago".
plt.scatter(x_axis, y_axis, color="r", label='Chicago')
# Add title and axis labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()
#invert y_axis so that Jan is on top
plt.gca().invert_yaxis()
# Add limit to the x-axis data
plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %%
#Change color to red and set legend to "Chicago".
plt.scatter(y_axis, x_axis, color="r", label='Chicago')
# Add title and axis labels.
plt.ylabel("Date")
plt.xlabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()
#invert y_axis so that Jan is on top
plt.gca().invert_yaxis()
# Add limit to the x-axis data
plt.xlim(0, 50)
# Out:
# (0.0, 50.0)

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Using the object-oriented interface method, create the same scatterplot
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Change the color of the markers to sky blue.
# Make the color 20% transparent.
# Change the size of the markers to 5 times each data point.
# Add a black edge color to the circles.
# Make the linewidth of the circles 2 points.
# Add a legend for the city of Boston.
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, [i * 5 for i in y_axis], facecolor="skyblue", edgecolors="black", linewidths=2, label="Boston", alpha=0.8

# Add a title.
ax.invert_yaxis()
ax.set_title("PyBer Fare by Month")
           
# Switch the axis so that the Fare($) data is on the x-axis.
ax.ylabel("Date")
ax.xlabel("Fare($)")

# Add a limit for the x-axis data.
ax.xlim(0, 50)
           
# Invert the y-axis so that January is at the top.
ax.gca().invert_yaxis()
# Out:
#   File "C:\Users\m163075\AppData\Local\Temp/ipykernel_6492/4112924557.py", line 11
#     ax.invert_yaxis()
#      ^
# SyntaxError: invalid syntax

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, [i * 5 for i in y_axis], facecolor="skyblue", edgecolors="black", linewidths=2, label="Boston", alpha=0.8)
plt.gca().invert_yaxis()
ax.set_title("PyBer Fare by Month")
ax.set_ylabel('Date')
ax.set_xlabel('Fare ($)')
ax.set_xlim(0,55)
# Out:
# (0.0, 55.0)

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, [i * 5 for i in y_axis], facecolor="skyblue", edgecolors="black", linewidths=2, label="Boston", alpha=0.8)
ax.invert_yaxis()
ax.set_title("PyBer Fare by Month")
ax.set_ylabel('Date')
ax.set_xlabel('Fare ($)')
ax.set_xlim(0,55)
# Out:
# (0.0, 55.0)

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x17561121188>,
#   <matplotlib.patches.Wedge at 0x17561121dc8>,
#   <matplotlib.patches.Wedge at 0x1756112ae48>,
#   <matplotlib.patches.Wedge at 0x1756112a8c8>,
#   <matplotlib.patches.Wedge at 0x17561138f48>,
#   <matplotlib.patches.Wedge at 0x17561143088>,
#   <matplotlib.patches.Wedge at 0x1756114b048>,
#   <matplotlib.patches.Wedge at 0x17561152088>,
#   <matplotlib.patches.Wedge at 0x17561138e88>,
#   <matplotlib.patches.Wedge at 0x1756113ef88>,
#   <matplotlib.patches.Wedge at 0x17561121108>,
#   <matplotlib.patches.Wedge at 0x1756116d048>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
#Add a percentage to one decimal place to each wedge of the pie.
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
#Increase the figure size to 8x8.
plt.subplots(figsize=(8, 8))

#Explode the two highest percentage months.
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

#Add a shadow.
#Add a start angle so that January is at the top.
#Reverse the order so that the month order is in a clockwise direction.
plt.pie(shadow=True, startangle=180, counterclock=True)

#Add new colors of your own choosing or use the colors from the previous pie chart.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/2358760888.py in <module>
#      10 #Add a start angle so that January is at the top.
#      11 #Reverse the order so that the month order is in a clockwise direction.
# ---> 12 plt.pie(shadow=True, startangle=180, counterclock=True)
#      13
#      14 #Add new colors of your own choosing or use the colors from the previous pie chart.
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
#Add a percentage to one decimal place to each wedge of the pie.
#Increase the figure size to 8x8.
#Explode the two highest percentage months.
#Add a shadow.
#Add a start angle so that January is at the top.
#Reverse the order so that the month order is in a clockwise direction.
#Add new colors of your own choosing or use the colors from the previous pie chart.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
plt.pie(shadow=True, startangle=180, counterclock=True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/3299736518.py in <module>
#      10 plt.subplots(figsize=(8, 8))
#      11 plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# ---> 12 plt.pie(shadow=True, startangle=180, counterclock=True)
#      13
#      14 plt.show()
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
ax.pie(shadow=True, startangle=180, counterclock=True)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6492/3256549673.py in <module>
#       5 fig, ax = plt.subplots(figsize=(8, 8))
#       6 ax.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# ----> 7 ax.pie(shadow=True, startangle=180, counterclock=True)
#       8 ax.show()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
#Add a percentage to one decimal place to each wedge of the pie.
#Increase the figure size to 8x8.
#Explode the two highest percentage months.
#Add a shadow.
#Add a start angle so that January is at the top.
#Reverse the order so that the month order is in a clockwise direction.
#Add new colors of your own choosing or use the colors from the previous pie chart.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
fig, ax = plt.subplots(figsize=(8, 8))
ax.pie(y_axis,
explode=explode_values,
colors=colors,
labels=x_axis,
autopct='%.1f%%', startangle=260)
ax.invert_yaxis()
plt.show()
